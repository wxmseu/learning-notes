# %% [markdown]
# pandas的merge相当于sql的join，将不同的表按key关联到一起
# merge的语法：
# pd.merge(left,right,how='inner',on=None,left_on=None,right_on=None,left_index=False,right_index=False,sort=True,suffixes=('_x','_y'),copy=Tuee,indicator=False,validate=None)
# - left,right:要merge 的df或者有名字的series
# - how：join类型，'left','right','outer','inner'
# - on: join的key，left和right都需要有key
# - left_on: left的df或者series的key
# - right_on: right的df或者series的key
# - left_index,right_index:使用index而不是普通的column做join
# - suffixes：两个元素的后缀，如果列有重名，自动添加后缀，默认是('_x','_y')

# %% [markdown]
# 本次项目共有三张表
# - 用户表：用户id，年龄，性别，职业，邮编
# - 电影表：电影id，电影名，类型
# - 评分表：userId，movieId，rating，timestamp
#
# 数据集链接：https://grouplens.org/datasets/movielens/

# %%
import pandas as pd
# 用户表
df_users=pd.read_csv('./data/movies/u.user',sep='|',names=['userId','age','gender','occupation','zip-code'])

# %%
# 将用户表导出成一个excel方便后面的拆分和合并使用
df_users.to_excel('./data/movies/users.xlsx',index=False)

# %%
df_users.tail()
# Out:
#      userId  age gender     occupation zip-code
# 938     939   26      F        student    33319
# 939     940   32      M  administrator    02215
# 940     941   20      M        student    97229
# 941     942   48      F      librarian    78209
# 942     943   22      M        student    77841

# %%
# 电影表
df_movies=pd.read_csv('./data/movies/movies.csv')
df_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_movies.count()
# Out:
# movieId    9742
# title      9742
# genres     9742
# dtype: int64

# %%
# 评分表
df_ratings=pd.read_csv('./data/movies/ratings.csv')

# %%
df_ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df_ratings.count()
# Out:
# userId       100836
# movieId      100836
# rating       100836
# timestamp    100836
# dtype: int64

# %%
# df_ratings_users=pd.merge(df_ratings,df_users,on='userId')
df_ratings_users=pd.merge(df_users,df_ratings,how='left',on='userId')

# %%
df_ratings_users.head()
# Out:
#    userId  age gender  occupation zip-code  movieId  rating    timestamp
# 0       1   24      M  technician    85711      1.0     4.0  964982703.0
# 1       1   24      M  technician    85711      3.0     4.0  964981247.0
# 2       1   24      M  technician    85711      6.0     4.0  964982224.0
# 3       1   24      M  technician    85711     47.0     5.0  964983815.0
# 4       1   24      M  technician    85711     50.0     5.0  964982931.0

# %%
df_ratings_users.count()
# Out:
# userId        101169
# age           101169
# gender        101169
# occupation    101169
# zip-code      101169
# movieId       100836
# rating        100836
# timestamp     100836
# dtype: int64

# %%
df_ratings_users.tail()
# Out:
#         userId  age gender     occupation zip-code  movieId  rating  timestamp
# 101164     939   26      F        student    33319      NaN     NaN        NaN
# 101165     940   32      M  administrator    02215      NaN     NaN        NaN
# 101166     941   20      M        student    97229      NaN     NaN        NaN
# 101167     942   48      F      librarian    78209      NaN     NaN        NaN
# 101168     943   22      M        student    77841      NaN     NaN        NaN

# %%
df_ratings_users.loc[df_ratings_users['userId']==456]
# Out:
#        userId  age gender  occupation zip-code  movieId  rating    timestamp
# 71257     456   24      M  technician    31820      1.0     5.0  856883308.0
# 71258     456   24      M  technician    31820      3.0     3.0  856883349.0
# 71259     456   24      M  technician    31820      5.0     3.0  856883349.0
# 71260     456   24      M  technician    31820      9.0     4.0  856883450.0
# 71261     456   24      M  technician    31820     32.0     3.0  856883308.0
# 71262     456   24      M  technician    31820     64.0     3.0  856883540.0
# 71263     456   24      M  technician    31820     65.0     2.0  856883450.0
# 71264     456   24      M  technician    31820     74.0     4.0  856883468.0
# 71265     456   24      M  technician    31820     79.0     2.0  856883417.0
# 71266     456   24      M  technician    31820    104.0     3.0  856883383.0
# 71267     456   24      M  technician    31820    135.0     3.0  856883417.0
# ...
